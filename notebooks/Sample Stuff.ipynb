# %% [markdown]
# ## Simple scatter plot

# %%
import numpy as np
import matplotlib.pyplot as plt

### Define an array from random numbers
xyz = np.random.random((100,3))

# %%
plt.scatter(xyz[:,0],xyz[:,1],c=xyz[:,2],alpha=0.5)
plt.title("Simple scatter plot")
plt.xlabel("X label")
plt.ylabel("Y label")
cbar = plt.colorbar()

# %% [markdown]
# ## Simple Linear Regression
# Using the diabetes data set from scikit-learn

# %%
## Load the data
from sklearn import datasets
diabetes = datasets.load_diabetes()

# %%
## Will only use the second feature
diabetes_X = diabetes['data'][:,np.newaxis,2]

## Split the data and targets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# %%
## Create a linear regression model and train it
from sklearn.linear_model import LinearRegression

regr = LinearRegression()
regr.fit(diabetes_X_train,diabetes_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
## Make predictions using the test data set
diabetes_y_pred = regr.predict(diabetes_X_test)

## Calculate metric
from sklearn.metrics import mean_squared_error, r2_score
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# ('Coefficients: \n', array([938.23786125]))
# Mean squared error: 2548.07
# Variance score: 0.47

# %%
# Plot outputs
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(diabetes_X_test,diabetes_y_test,color='black',s=50,label='Test data')
plt.scatter(diabetes_X_train,diabetes_y_train,color='red',s=15, alpha = 0.3, label='Train data')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3, label='Trained model')
plt.xlabel('Body mass index (au)')
plt.ylabel('Desease projection (au)')
plt.legend()
plt.show()

# %% [markdown]
# ## Full linear regression on Diabetes dataset
# Start with a scattering matrix

# %%
diabetes.data[0]
# Out:
# array([ 0.03807591,  0.05068012,  0.06169621,  0.02187235, -0.0442235 ,
#        -0.03482076, -0.04340085, -0.00259226,  0.01990842, -0.01764613])

# %% [markdown]
# ## Histograms (log scale)

# %%
len(xyz[:,0])
# Out:
# 100

# %%
plt.hist(xyz[:,0],range=[0.2,0.7],cumulative=True,log=True,color='green')
# Out:
# (array([ 6., 12., 14., 16., 19., 24., 27., 33., 42., 45.]),
#  array([0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 ]),
#  <a list of 10 Patch objects>)

# %%
diabetes_X_train
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...
